# %% [markdown]
# <a href="https://colab.research.google.com/github/anastasiarenata1/deeplearning/blob/main/CIFAR%20Visualization%20and%20NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Visualizing CIFAR

# %%
from keras.datasets import cifar10
from matplotlib import pyplot as plt
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
# %matplotlib inline

# %%
(train_x, train_y), (test_x, test_y)= cifar10.load_data()
print(train_x.shape, train_y.shape)
print(test_x.shape, test_y.shape)
# Out:
# ...
# 170498071/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
categories= ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, ax= plt.subplots(nrows=3, ncols=10, figsize=(12,5))
for i in range(10):
  index= np.where(train_y.flatten() == i)[0][:3] #Filter first 3 images
  for j, index in enumerate(index):
    ax[j,i].imshow(train_x[index])
    ax[j,i].set_title(categories[i])
plt.show()

# %% [markdown]
# 2. Playing with Numpy

# %%
def gaussian(n, m):
    g= np.random.normal(0, 1, size=(n, m, 2))
    return g

# %%
grid = gaussian(10, 10)
plt.scatter(grid[:, :, 0], grid[:,:, 1])
plt.show()
